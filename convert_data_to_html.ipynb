# %%
import pandas as pd
import os

# %%
file_path=("Resources/cities.csv")
cities_df=pd.read_csv(file_path)

# %%
cities_df.head()
# Out:
#    Unnamed: 0         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           0      mataura -46.1927  168.8643     75.00      52.0       100.0
# 1           1      samarai -10.6167  150.6667     82.24      74.0       100.0
# 2           2  port alfred -33.5906   26.8910     69.01      95.0        88.0
# 3           3    egvekinot  66.3167 -179.1667    -15.38      87.0        62.0
# 4           4       atuona  -9.8000 -139.0333     78.35      76.0         3.0
#
#    Wind Speed Country          Date
# 0       10.00      NZ  1.611696e+09
# 1        6.96      PG  1.611696e+09
# 2        1.01      ZA  1.611696e+09
# 3       12.24      RU  1.611696e+09
# 4       16.55      PF  1.611696e+09

# %%
cities_df.columns
# Out:
# Index(['Unnamed: 0', 'City', 'Lat', 'Lng', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
cities_df=cities_df.drop(['Unnamed: 0'], axis=1)

# %%
cities_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      mataura -46.1927  168.8643     75.00      52.0       100.0       10.00
# 1      samarai -10.6167  150.6667     82.24      74.0       100.0        6.96
# 2  port alfred -33.5906   26.8910     69.01      95.0        88.0        1.01
# 3    egvekinot  66.3167 -179.1667    -15.38      87.0        62.0       12.24
# 4       atuona  -9.8000 -139.0333     78.35      76.0         3.0       16.55
#
#   Country          Date
# 0      NZ  1.611696e+09
# 1      PG  1.611696e+09
# 2      ZA  1.611696e+09
# 3      RU  1.611696e+09
# 4      PF  1.611696e+09

# %%
clean_city_df=cities_df.dropna()

# %%
cities_df.count()
# Out:
# City          630
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       577
# Date          582
# dtype: int64

# %%
clean_city_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# date_only=pd.to_datetime(clean_city_df['Date']).dt.date

# %%
# clean_city_df['date only'] = date_only
# Out:
# <ipython-input-35-df7db18c43ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_city_df['date only'] = date_only

# %%
# clean_city_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         mataura -46.1927  168.8643     75.00      52.0       100.0
# 1         samarai -10.6167  150.6667     82.24      74.0       100.0
# 2     port alfred -33.5906   26.8910     69.01      95.0        88.0
# 3       egvekinot  66.3167 -179.1667    -15.38      87.0        62.0
# 4          atuona  -9.8000 -139.0333     78.35      76.0         3.0
# ..            ...      ...       ...       ...       ...         ...
# 625    bani walid  31.7566   13.9942     51.03      60.0         0.0
# 626       gizycko  54.0381   21.7644     30.88      98.0       100.0
# 627       dolinsk  47.3500  142.8000      6.80      92.0        75.0
# 628        nangal  31.3667   76.3833     48.81      54.0         0.0
# 629  port augusta -32.5000  137.7667     66.20      72.0        90.0
#
#      Wind Speed Country          Date   date only
# 0         10.00      NZ  1.611696e+09  1970-01-01
# ...

# %%
html=clean_city_df.to_html()

# %%
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>mataura</td>
#       <td>-46.1927</td>
#       <td>168.8643</td>
#       <td>75.00</td>
#       <td>52.0</td>
#       <td>100.0</td>
#       <td>10.00</td>
#       <td>NZ</td>
#       <td>1.611696e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>samarai</td>
#       <td>-10.6167</td>
#       <td>150.6667</td>
#       <td>82.24</td>
#       <td>74.0</td>
#       <td>100.0</td>
#       <td>6.96</td>
#       <td>PG</td>
#       <td>1.611696e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>port alfred</td>
#       <td>-33.5906</td>
#       <td>26.8910</td>
# ...
